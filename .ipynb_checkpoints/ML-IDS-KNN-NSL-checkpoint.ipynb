# %% [markdown]
# # KNN - NSL

# %%
cd C:\\Users\\Sharuka Thirimanne\\Desktop\\FYP-ML-IDS
# Out:
# C:\Users\Sharuka Thirimanne\Desktop\FYP-ML-IDS

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score

# %%
def load_train_dataset():
    df_train = pd.read_csv('NSL_train-set.csv')
    
    limit = df_train.shape[1]-1
    
    X_train = df_train.iloc[:,0:limit]
    Y_train = df_train.iloc[:,limit]
    
    return X_train, Y_train, df_train

X_train, Y_train, df_train = load_train_dataset()

# %%
def load_test_dataset():
    df_test = pd.read_csv('NSL_test-set.csv')

    limit = df_test.shape[1]-1
    
    X_test = df_test.iloc[:,0:limit]
    Y_test = df_test.iloc[:,limit]
    
    return X_test, Y_test, df_test

X_test, Y_test, df_test = load_test_dataset()

# %%
X_train, X_val , Y_train , Y_val = train_test_split(X_train,Y_train, test_size=0.065,stratify = Y_train,shuffle=True,random_state=42)

print('Training X   :',X_train.shape)
print('Validation X :',X_val.shape)
print('Test_X       :',X_test.shape)
print('Training_Y   :',Y_train.shape)
print('Validation Y :',Y_val.shape)
print('Test_Y       :',Y_test.shape)
# Out:
# Training X   : (99854, 62)
# Validation X : (6942, 62)
# Test_X       : (22310, 62)
# Training_Y   : (99854,)
# Validation Y : (6942,)
# Test_Y       : (22310,)

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = 8, p = 1, weights ='distance').fit(X_train,Y_train)

# %%
test_predictions = knn_classifier.predict(X_test)

print("Cross-Validation set accuracy: {:.6f} %".format((cross_val_score(knn_classifier, X_val, Y_val, 
                                                                        cv=3,scoring='accuracy').mean())*100))
print("Train set accuracy           : {:.6f} %".format(knn_classifier.score(X_train,Y_train)*100))
print("Test set accuracy            : {:.6f} %".format(accuracy_score(Y_test, test_predictions)*100))
# Out:
# Cross-Validation set accuracy: 98.689139 %
# Train set accuracy           : 99.993991 %
# Test set accuracy            : 78.471537 %

# %%
def plot_cm(labels, predictions, p=0.81):
    cm = confusion_matrix(labels, predictions > p)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title('Confusion matrix @{:.2f}'.format(p))
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    plt.text(0.3,2.6,'True Negatives  : '+ str(cm[0][0]),size=14)
    plt.text(0.3,2.8,'False Positives   : '+ str(cm[0][1]),size=14)
    plt.text(0.3,3,'False Negatives : '+ str(cm[1][0]),size=14)
    plt.text(0.3,3.2,'True Positives    : '+ str(cm[1][1]),size=14)

# %%
plot_cm(Y_test, test_predictions)

# %%
print(classification_report(Y_test, test_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.93      0.78      9711
#            1       0.92      0.65      0.76     12833
#
#     accuracy                           0.77     22544
#    macro avg       0.80      0.79      0.77     22544
# weighted avg       0.81      0.77      0.77     22544

# %%
knn_classifier.get_params().keys()
# Out:
# dict_keys(['algorithm', 'leaf_size', 'metric', 'metric_params', 'n_jobs', 'n_neighbors', 'p', 'weights'])

# %%
n_neighbors = list(range(1,50,2))
p=[1,2]

param_grid = [{'n_neighbors' : n_neighbors,
               'p':p,
               'weights':['uniform','distance'],
               'algorithm':['ball_tree','kd_tree','brute']
              },]

optimal_params = GridSearchCV(
    estimator = knn_classifier,
    param_grid = param_grid,
    cv=2,
    scoring ='accuracy',
    verbose = 2)

optimal_params.fit(X_val,Y_val)
print(optimal_params.best_params_)
# Out:
# Fitting 2 folds for each of 300 candidates, totalling 600 fits
# [CV] algorithm=ball_tree, n_neighbors=1, p=1, weights=uni
p=2, weights=uniform, total=   0.2s
# [CV] algorithm=kd_tree, n_neighbors=29, p=2, weights=uniform .........
# [CV]  algorithm=kd_tree, n_neighbors=29, p=2, weights=uniform, total=   0.2s
# [CV] algorithm=kd_tree, n_neighbors=29, p=2, weights=distance ........
# [CV]  algorithm=kd_tree, n_neighbors=29, p=2, weights=distance, total=   0.1s
# [CV] algorithm=kd_tree, n_neighbors=29, p=2, weights=distance ........
# ...
# [CV] algorithm=brute, n_neighbors=23, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=23, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=23, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=23, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=23, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=23, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=23, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=23, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=25, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=25, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=25, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=25, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=25, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=25, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=25, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=25, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=25, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=25, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=25, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=25, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=25, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=25, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=25, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=25, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=27, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=27, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=27, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=27, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=27, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=27, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=27, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=27, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=27, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=27, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=27, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=27, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=27, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=27, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=27, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=27, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=29, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=29, p=1, weights=uniform, total=   0.8s
# [CV] algorithm=brute, n_neighbors=29, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=29, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=29, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=29, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=29, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=29, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=29, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=29, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=29, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=29, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=29, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=29, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=29, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=29, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=31, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=31, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=31, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=31, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=31, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=31, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=31, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=31, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=31, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=31, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=31, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=31, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=31, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=31, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=31, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=31, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=33, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=33, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=33, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=33, p=1, weights=uniform, total=   0.8s
# [CV] algorithm=brute, n_neighbors=33, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=33, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=33, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=33, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=33, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=33, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=33, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=33, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=33, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=33, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=33, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=33, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=35, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=35, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=35, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=35, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=35, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=35, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=35, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=35, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=35, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=35, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=35, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=35, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=35, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=35, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=35, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=35, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=37, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=37, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=37, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=37, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=37, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=37, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=37, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=37, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=37, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=37, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=37, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=37, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=37, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=37, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=37, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=37, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=39, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=39, p=1, weights=uniform, total=   0.8s
# [CV] algorithm=brute, n_neighbors=39, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=39, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=39, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=39, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=39, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=39, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=39, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=39, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=39, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=39, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=39, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=39, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=39, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=39, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=41, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=41, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=41, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=41, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=41, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=41, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=41, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=41, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=41, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=41, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=41, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=41, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=41, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=41, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=41, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=41, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=43, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=43, p=1, weights=uniform, total=   0.8s
# [CV] algorithm=brute, n_neighbors=43, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=43, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=43, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=43, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=43, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=43, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=43, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=43, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=43, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=43, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=43, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=43, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=43, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=43, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=45, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=45, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=45, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=45, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=45, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=45, p=1, weights=distance, total=   0.7s
# [CV] algorithm=brute, n_neighbors=45, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=45, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=45, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=45, p=2, weights=uniform, total=   0.6s
# [CV] algorithm=brute, n_neighbors=45, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=45, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=45, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=45, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=45, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=45, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=47, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=47, p=1, weights=uniform, total=   0.8s
# [CV] algorithm=brute, n_neighbors=47, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=47, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=47, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=47, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=47, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=47, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=47, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=47, p=2, weights=uniform, total=   0.4s
# [CV] algorithm=brute, n_neighbors=47, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=47, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=47, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=47, p=2, weights=distance, total=   0.3s
# [CV] algorithm=brute, n_neighbors=47, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=47, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=49, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=49, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=49, p=1, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=49, p=1, weights=uniform, total=   0.7s
# [CV] algorithm=brute, n_neighbors=49, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=49, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=49, p=1, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=49, p=1, weights=distance, total=   0.6s
# [CV] algorithm=brute, n_neighbors=49, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=49, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=49, p=2, weights=uniform ...........
# [CV]  algorithm=brute, n_neighbors=49, p=2, weights=uniform, total=   0.5s
# [CV] algorithm=brute, n_neighbors=49, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=49, p=2, weights=distance, total=   0.4s
# [CV] algorithm=brute, n_neighbors=49, p=2, weights=distance ..........
# [CV]  algorithm=brute, n_neighbors=49, p=2, weights=distance, total=   0.4s
# {'algorithm': 'ball_tree', 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# [Parallel(n_jobs=1)]: Done 600 out of 600 | elapsed:  2.6min finished

# %%
def plot_decision_boundary(X, y, classifier_name):
    
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF','#AFAFAF'])
    cmap_bold  = ListedColormap(['#FF0000', '#00FF00', '#0000FF','#2721d1'])

    h = 0.02
    x_min, x_max = X[:,0].min() - 0.1, X[:,0].max() + 0.1
    y_min, y_max = X[:,1].min() - 0.1, X[:,1].max() + 0.1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = classifier_name.predict(np.c_[xx.ravel(), yy.ravel()])
    
    Z = Z.reshape(xx.shape)
    plt.figure(1, figsize=(10, 10))
    plt.pcolormesh(xx, yy,Z,cmap=cmap_light)
    plt.scatter(X[:, 0], X[:, 1], s=40, c=y, cmap=cmap_bold)
    #plt.imshow(Z, interpolation='nearest', cmap=cmap_bold, alpha=0.15, extent=(x_min, x_max, y_min, y_max), origin='lower')
    plt.title("{} neighbor(s)".format(6))
    
    patch0 = mpatches.Patch(color='#FFFF00', label='Normal')
    patch1 = mpatches.Patch(color='#000000', label='Anomaly')
    plt.legend(handles=[patch0, patch1])
    #plt.title(plot_type + '\n' + str(classifier_name).split('(')[0]+ ' Test Accuracy: ' + str(np.round(classifier_name.score(X, y), 5)))
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.show()
     

#plt.set_cmap(plt.cm.Paired)
#plt.pcolormesh(xx, yy,Z,cmap=cmap_light)

# %%
import matplotlib.patches as mpatches

# %%
X = X_test[:,0:2]

knn = neighbors.KNeighborsClassifier(n_neighbors = 6, p = 1, weights ='distance').fit(X, Y_test)
plot_decision_boundary(X, Y_test, knn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9a6d72a0deb8> in <module>
# ----> 1 X =X_test[:,0:2]
#       2
#       3 knn = neighbors.KNeighborsClassifier(n_neighbors = 6, p = 1, weights ='distance').fit(X, Y_test)
#       4 plot_decision_boundary(X, Y_test, knn)
#
# c:\users\sharuka thirimanne\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# c:\users\sharuka thirimanne\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(0, 2, None))' is an invalid key

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X_test)
principalDf = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])
principal_Y = pd.DataFrame(Y_test)

# %%
X = principalDf.values
y = principal_Y.values

# %%
plot_decision_boundary(X, y, knn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7468183b30fa> in <module>
# ----> 1 plot_decision_boundary(X, y, knn)
#
# NameError: name 'knn' is not defined

# %%
train_acc = knn.score(principalDf,y)
#cv_acc = pipe.score(val_X,val_Y)
test_predictions = knn.predict(principal_test)

print('Train Accuracy = '+str(train_acc * 100)+' %')
#print('Cross Validation Accuracy = '+str(cv_acc * 100)+' %')
print('Accuracy Test : '+ str(accuracy_score(test_Y, test_predictions)*100)+' %')
# Out:
# Train Accuracy = 99.76046841731726 %
# Accuracy Test : 99.48988644428673 %

# %%
from sklearn.model_selection import validation_curve
param_range = np.arange(1,50,2)

training_scores, test_scores = validation_curve(knn_classifier,X_train,Y_train, 
                          param_name = 'n_neighbors',
                          param_range=param_range,
                          cv = 2,
                          scoring = 'f1_weighted',
                          verbose=2)
train_score = np.mean(training_scores, axis=1)
test_score = np.mean(test_scores, axis=1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] n_neighbors=1 ...................................................
# [CV] .................................... n_neighbors=1, total= 2.4min
# [CV] n_neighbors=3 ...................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.6min remaining:    0.0s
# [CV] .................................... n_neighbors=3, total= 2.5min
# [CV] n_neighbors=5 ...................................................
# [CV] .................................... n_neighbors=5, total= 2.6min
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=7, total= 3.6min
# [CV] n_neighbors=9 ...................................................
# [CV] .................................... n_neighbors=9, total= 3.1min
# [CV] n_neighbors=11 ..................................................
# [CV] ................................... n_neighbors=11, total= 3.0min
# [CV] n_neighbors=13 ..................................................
# [CV] ................................... n_neighbors=13, total= 4.1min
# [CV] n_neighbors=15 ..................................................
# [CV] ................................... n_neighbors=15, total= 4.6min
# [CV] n_neighbors=17 ..................................................
# [CV] ................................... n_neighbors=17, total= 3.1min
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=19, total= 2.7min
# [CV] n_neighbors=21 ..................................................
# [CV] ................................... n_neighbors=21, total= 2.7min
# [CV] n_neighbors=23 ..................................................
# [CV] ................................... n_neighbors=23, total= 2.7min
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=25, total= 2.7min
# [CV] n_neighbors=27 ..................................................
# [CV] ................................... n_neighbors=27, total= 2.7min
# [CV] n_neighbors=29 ..................................................
# [CV] ................................... n_neighbors=29, total= 2.7min
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=31, total= 2.8min
# [CV] n_neighbors=33 ..................................................
# [CV] ................................... n_neighbors=33, total= 2.8min
# [CV] n_neighbors=35 ..................................................
# [CV] ................................... n_neighbors=35, total= 2.8min
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=37, total= 2.8min
# [CV] n_neighbors=39 ..................................................
# [CV] ................................... n_neighbors=39, total= 2.8min
# [CV] n_neighbors=41 ..................................................
# [CV] ................................... n_neighbors=41, total= 2.9min
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=43, total= 3.0min
# [CV] n_neighbors=45 ..................................................
# [CV] ................................... n_neighbors=45, total= 2.9min
# [CV] n_neighbors=47 ..................................................
# [CV] ................................... n_neighbors=47, total= 2.9min
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=49, total= 2.9min
# [CV] n_neighbors=1 ...................................................
# [CV] .................................... n_neighbors=1, total= 2.3min
# [CV] n_neighbors=3 ...................................................
# [CV] .................................... n_neighbors=3, total= 2.4min
# [CV] n_neighbors=5 ...................................................
# [CV] .................................... n_neighbors=5, total= 2.5min
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=7, total= 2.5min
# [CV] n_neighbors=9 ...................................................
# [CV] .................................... n_neighbors=9, total= 2.5min
# [CV] n_neighbors=11 ..................................................
# [CV] ................................... n_neighbors=11, total= 2.5min
# [CV] n_neighbors=13 ..................................................
# [CV] ................................... n_neighbors=13, total= 2.5min
# [CV] n_neighbors=15 ..................................................
# [CV] ................................... n_neighbors=15, total= 2.6min
# [CV] n_neighbors=17 ..................................................
# [CV] ................................... n_neighbors=17, total= 2.6min
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=19, total= 2.6min
# [CV] n_neighbors=21 ..................................................
# [CV] ................................... n_neighbors=21, total= 2.4min
# [CV] n_neighbors=23 ..................................................
# [CV] ................................... n_neighbors=23, total= 2.4min
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=25, total= 2.4min
# [CV] n_neighbors=27 ..................................................
# [CV] ................................... n_neighbors=27, total= 2.4min
# [CV] n_neighbors=29 ..................................................
# [CV] ................................... n_neighbors=29, total= 2.4min
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=31, total= 2.5min
# [CV] n_neighbors=33 ..................................................
# [CV] ................................... n_neighbors=33, total= 2.5min
# [CV] n_neighbors=35 ..................................................
# [CV] ................................... n_neighbors=35, total= 2.5min
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=37, total= 2.5min
# [CV] n_neighbors=39 ..................................................
# [CV] ................................... n_neighbors=39, total= 2.5min
# [CV] n_neighbors=41 ..................................................
# [CV] ................................... n_neighbors=41, total= 2.5min
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=43, total= 2.5min
# [CV] n_neighbors=45 ..................................................
# [CV] ................................... n_neighbors=45, total= 3.3min
# [CV] n_neighbors=47 ..................................................
# [CV] ................................... n_neighbors=47, total= 3.2min
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=49, total= 2.6min
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 266.8min finished

# %%
plt.figure(figsize=(10,5))
plt.plot(param_range, train_score, '-o' , label='training data', markersize=10)
plt.plot(param_range, test_score, '-o' , label='test data', markersize=10)
plt.ylim(-0.9001,1.2001)
plt.xticks(param_range)
plt.legend(loc=2)

# %%
i = 0
dict = {}
for neighbor, score in zip(param_range,zip(train_score,test_score)):
    dict[i] = {'n_neighbor': neighbor, 
            'train_score': score[0],
            'test_score':score[1]}
    i += 1

val_df = pd.DataFrame(dict).T
val_df
# Out:
#     n_neighbor  train_score  test_score
# 0          1.0      0.99996    0.994993
# 1          3.0      0.99996    0.994883
# 2          5.0      0.99996    0.994582
# 3          7.0      0.99996    0.994362
# 4          9.0      0.99996    0.994232
# 5         11.0      0.99996    0.994232
# 6         13.0      0.99996    0.994141
# 7         15.0      0.99996    0.993931
# 8         17.0      0.99996    0.993801
# 9         19.0      0.99996    0.993891
# 10        21.0      0.99996    0.993781
# 11        23.0      0.99996    0.993621
# 12        25.0      0.99996    0.993611
# 13        27.0      0.99996    0.993581
# 14        29.0      0.99996    0.993581
# 15        31.0      0.99996    0.993521
# 16        33.0      0.99996    0.993420
# 17        35.0      0.99996    0.993270
# 18        37.0      0.99996    0.993190
# 19        39.0      0.99996    0.993210
# 20        41.0      0.99996    0.993130
# 21        43.0      0.99996    0.993120
# 22        45.0      0.99996    0.993010
# 23        47.0      0.99996    0.992910
# 24        49.0      0.99996    0.992799

# %%
print('Max. Test Score: ',val_df['test_score'].max())
print('Max. Test Score index: ',val_df['test_score'].idxmax())
# Out:
# Max. Test Score:  0.9949926888751628
# Max. Test Score index:  0
