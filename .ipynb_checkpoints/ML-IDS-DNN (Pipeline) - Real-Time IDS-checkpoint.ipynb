# %%
cd /media/sharukathirimanne/OS/Users/Sharuka Thirimanne/Desktop/FYP-ML-IDS
# Out:
# /media/sharukathirimanne/OS/Users/Sharuka Thirimanne/Desktop/FYP-ML-IDS

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import kerastuner as kt
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras import Model, layers
from sklearn.model_selection import cross_val_score
from keras.regularizers import l2
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from kerastuner.tuners import RandomSearch
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, confusion_matrix,f1_score

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

#Pipelines
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import KFold
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer

# Pipeline Saving
from pickle import dump
from io import StringIO
import joblib
from keras.models import model_from_json
import json

import datetime

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/
# Out:
# rm: cannot remove './logs/fit/20210529-203644/train': Directory not empty
# rm: cannot remove './logs/fit/20210529-203644/validation': Directory not empty

# %% [markdown]
# # ML Model Training

# %%
def train_preprocess():
    df_train = pd.read_csv('Datasets/csv_result-KDDTrain+.csv')
    df_train.drop(['id'], axis = 'columns' , inplace = True)
    
    col_list = ['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent',
                'count','srv_count','serror_rate','srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate',
                'diff_srv_rate','srv_diff_host_rate','dst_host_count','dst_host_srv_count','dst_host_same_srv_rate',
                'dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate',
                'dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate','class']
    
    df_train = df_train[col_list]
    
    #for i in range(11,20):
        #df_train.drop(df_train.columns[i],axis='columns',inplace=True)
        
    num_features = len(df_train.columns) - 1
    print('Number of features before feature selection :',num_features)
    print('Original dataset duplicates :',df_train.duplicated().sum())

    num_features = len(df_train.columns) - 1
    print('Number of features after feature selection :',num_features)
    print('Duplicates after feature selection :',df_train.duplicated().sum())
    for col in ['protocol_type','flag','service']:
        df_train[col] = df_train[col].astype('category')
    
    label1 = 'Other_service'
    others1 = df_train['service'].value_counts().index[30:]
    df_train['service'] = df_train['service'].cat.add_categories([label1])
    df_train['service'] = df_train['service'].replace(others1, label1)

    df_train['service'].replace({'time':'Other_service','urp_i':'Other_service',
                                 'csnet_ns':'Other_service','supdup':'Other_service',
                                 'discard':'Other_service','http_443':'Other_service'}, inplace = True)
    
    print('Duplicates after category reduction :',df_train.duplicated().sum())
    df_train['class'] = df_train['class'].map( {'normal':0, 'anomaly':1} )
    df_train.drop_duplicates(keep='first',inplace=True)
    print('Duplicates after duplicate drop :',df_train.duplicated().sum())
    df_train.reset_index(drop=True,inplace=True)
    
    return df_train
df_train = train_preprocess()
# Out:
# Number of features before feature selection : 28
# Original dataset duplicates : 27
# Number of features after feature selection : 28
# Duplicates after feature selection : 27
# Duplicates after category reduction : 1486
# Duplicates after duplicate drop : 0

# %%
print(df_train['protocol_type'].value_counts())
print('======================================')
print(df_train['service'].value_counts())
print('======================================')
print(df_train['flag'].value_counts())
# Out:
# tcp     101212
# udp      14993
# icmp      8282
# Name: protocol_type, dtype: int64
# ======================================
# http             40332
# private          21853
# Other_service    12075
# domain_u          9043
# smtp              7313
# ftp_data          6848
# eco_i             4582
# other             4359
# ecr_i             3072
# telnet            2353
# finger            1767
# ftp               1754
# auth               955
# Z39_50             862
# uucp               780
# courier            734
# bgp                710
# whois              693
# uucp_path          689
# iso_tsap           687
# imap4              647
# nnsp               630
# vmnet              617
# domain             569
# ctf                563
# Name: service, dtype: int64
# ======================================
# SF        74918
# S0        33653
# REJ       11058
# RSTR       2389
# RSTO       1527
# S1          365
# SH          252
# S2          127
# RSTOS0      103
# S3           49
# OTH          46
# Name: flag, dtype: int64

# %%
df_train.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'count', 'srv_count',
#        'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
#        'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
#        'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'class'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (124487, 29)

# %%
limit1 = df_train.shape[1]-1
    
X_train = df_train.iloc[:,0:limit1] # train set features
y_train = df_train.iloc[:,limit1]

# %%
df_train.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'count', 'srv_count',
#        'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
#        'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
#        'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'class'],
#       dtype='object')

# %%
categorical_cols = ['protocol_type','flag','service']
std_cols = ['duration','src_bytes','dst_bytes', 'land', 'wrong_fragment', 'urgent', 'count', 'srv_count','serror_rate',
            'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate','same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
            'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate','dst_host_diff_srv_rate',
            'dst_host_same_src_port_rate','dst_host_srv_diff_host_rate', 'dst_host_serror_rate','dst_host_srv_serror_rate',
            'dst_host_rerror_rate','dst_host_srv_rerror_rate']

# %%
X_train.shape
# Out:
# (124487, 28)

# %%
ohe = OneHotEncoder()
std_scaler = StandardScaler()

columnTransformer = make_column_transformer(
    ( ohe, categorical_cols),
    (std_scaler,std_cols), 
    remainder='passthrough')

X_train = columnTransformer.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (124487, 64)

# %%
METRICS = [ 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),]

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='accuracy', 
    verbose=1,
    patience=3,
    mode='max',
    restore_best_weights=True)

# %%
initializer = tf.keras.initializers.GlorotUniform()

#Neural Network Model
model = Sequential()
model.add(Dense(256, input_dim=64, activation='relu', kernel_initializer=initializer,
                kernel_regularizer=l2(0.001), bias_initializer='zeros'))
model.add(layers.Dense(units= 320,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 320,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 224,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 256,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 384,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 160,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 192,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 224,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 224,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 32 ,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 352,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 256,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 448,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 64 ,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 128,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 352,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 64 ,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 128,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(layers.Dense(units= 160,kernel_regularizer=l2(0.001),activation = 'relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adam(learning_rate = 0.001),metrics = METRICS)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

history = model.fit(x=X_train, y=y_train, epochs=50, validation_split=0.25, 
                    callbacks=[tensorboard_callback, early_stopping])
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ModuleWrapper has arguments in `__init__` and therefore must override `get_config`.
# Epoch 1/50
# 2918/2918 [==============================] - 36s 9ms/step - loss: 0.1399 - accuracy: 0.9202 - precision: 0.9329 - recall: 0.8489 - auc: 0.9656 - val_loss: 0.0666 - val_accuracy: 0.9737 - val_precision: 0.9825 - val_recall: 0.9600 - val_auc: 0.9955
# Epoch 2/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0715 - accuracy: 0.9757 - precision: 0.9852 - recall: 0.9615 - auc: 0.9961 - val_loss: 0.0687 - val_accuracy: 0.9769 - val_precision: 0.9847 - val_recall: 0.9648 - val_auc: 0.9966
# Epoch 3/50
# 2918/2918 [==============================] - 27s 9ms/step - loss: 0.0683 - accuracy: 0.9771 - precision: 0.9826 - recall: 0.9674 - auc: 0.9968 - val_loss: 0.0574 - val_accuracy: 0.9785 - val_precision: 0.9820 - val_recall: 0.9709 - val_auc: 0.9972
# Epoch 4/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0529 - accuracy: 0.9791 - precision: 0.9819 - recall: 0.9724 - auc: 0.9973 - val_loss: 0.0510 - val_accuracy: 0.9800 - val_precision: 0.9822 - val_recall: 0.9740 - val_auc: 0.9975
# Epoch 5/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.1382 - accuracy: 0.9803 - precision: 0.9826 - recall: 0.9745 - auc: 0.9976 - val_loss: 0.0617 - val_accuracy: 0.9810 - val_precision: 0.9833 - val_recall: 0.9752 - val_auc: 0.9976
# Epoch 6/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.1303 - accuracy: 0.9813 - precision: 0.9838 - recall: 0.9754 - auc: 0.9977 - val_loss: 0.0430 - val_accuracy: 0.9820 - val_precision: 0.9846 - val_recall: 0.9761 - val_auc: 0.9978
# Epoch 7/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0467 - accuracy: 0.9824 - precision: 0.9850 - recall: 0.9765 - auc: 0.9979 - val_loss: 0.0601 - val_accuracy: 0.9828 - val_precision: 0.9853 - val_recall: 0.9771 - val_auc: 0.9979
# Epoch 8/50
# 2918/2918 [==============================] - 25s 9ms/step - loss: 0.0452 - accuracy: 0.9830 - precision: 0.9855 - recall: 0.9773 - auc: 0.9979 - val_loss: 0.0582 - val_accuracy: 0.9836 - val_precision: 0.9861 - val_recall: 0.9781 - val_auc: 0.9980
# Epoch 9/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0402 - accuracy: 0.9838 - precision: 0.9862 - recall: 0.9784 - auc: 0.9981 - val_loss: 0.0375 - val_accuracy: 0.9842 - val_precision: 0.9866 - val_recall: 0.9790 - val_auc: 0.9982
# Epoch 10/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0388 - accuracy: 0.9844 - precision: 0.9867 - recall: 0.9793 - auc: 0.9982 - val_loss: 0.0558 - val_accuracy: 0.9848 - val_precision: 0.9871 - val_recall: 0.9798 - val_auc: 0.9983
# Epoch 11/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0389 - accuracy: 0.9849 - precision: 0.9872 - recall: 0.9799 - auc: 0.9982 - val_loss: 0.0339 - val_accuracy: 0.9853 - val_precision: 0.9875 - val_recall: 0.9804 - val_auc: 0.9983
# Epoch 12/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0361 - accuracy: 0.9854 - precision: 0.9876 - recall: 0.9806 - auc: 0.9983 - val_loss: 0.0674 - val_accuracy: 0.9857 - val_precision: 0.9879 - val_recall: 0.9808 - val_auc: 0.9984
# Epoch 13/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0641 - accuracy: 0.9858 - precision: 0.9881 - recall: 0.9809 - auc: 0.9984 - val_loss: 0.0365 - val_accuracy: 0.9860 - val_precision: 0.9883 - val_recall: 0.9812 - val_auc: 0.9984
# Epoch 14/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0347 - accuracy: 0.9862 - precision: 0.9884 - recall: 0.9814 - auc: 0.9984 - val_loss: 0.0367 - val_accuracy: 0.9864 - val_precision: 0.9886 - val_recall: 0.9816 - val_auc: 0.9985
# Epoch 15/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0341 - accuracy: 0.9865 - precision: 0.9887 - recall: 0.9818 - auc: 0.9985 - val_loss: 0.0349 - val_accuracy: 0.9867 - val_precision: 0.9888 - val_recall: 0.9821 - val_auc: 0.9985
# Epoch 16/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0338 - accuracy: 0.9868 - precision: 0.9889 - recall: 0.9822 - auc: 0.9985 - val_loss: 0.0371 - val_accuracy: 0.9869 - val_precision: 0.9891 - val_recall: 0.9824 - val_auc: 0.9985
# Epoch 17/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0320 - accuracy: 0.9870 - precision: 0.9892 - recall: 0.9824 - auc: 0.9985 - val_loss: 0.0360 - val_accuracy: 0.9871 - val_precision: 0.9894 - val_recall: 0.9825 - val_auc: 0.9986
# Epoch 18/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0337 - accuracy: 0.9872 - precision: 0.9895 - recall: 0.9825 - auc: 0.9986 - val_loss: 0.0378 - val_accuracy: 0.9873 - val_precision: 0.9896 - val_recall: 0.9827 - val_auc: 0.9986
# Epoch 19/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0342 - accuracy: 0.9874 - precision: 0.9897 - recall: 0.9828 - auc: 0.9986 - val_loss: 0.0350 - val_accuracy: 0.9875 - val_precision: 0.9899 - val_recall: 0.9829 - val_auc: 0.9986
# Epoch 20/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0350 - accuracy: 0.9876 - precision: 0.9899 - recall: 0.9830 - auc: 0.9986 - val_loss: 0.0331 - val_accuracy: 0.9877 - val_precision: 0.9900 - val_recall: 0.9831 - val_auc: 0.9986
# Epoch 21/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0363 - accuracy: 0.9878 - precision: 0.9901 - recall: 0.9832 - auc: 0.9986 - val_loss: 0.0347 - val_accuracy: 0.9878 - val_precision: 0.9901 - val_recall: 0.9833 - val_auc: 0.9986
# Epoch 22/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0339 - accuracy: 0.9879 - precision: 0.9902 - recall: 0.9834 - auc: 0.9986 - val_loss: 0.0293 - val_accuracy: 0.9880 - val_precision: 0.9902 - val_recall: 0.9836 - val_auc: 0.9986
# Epoch 23/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0335 - accuracy: 0.9881 - precision: 0.9903 - recall: 0.9837 - auc: 0.9987 - val_loss: 0.0388 - val_accuracy: 0.9882 - val_precision: 0.9903 - val_recall: 0.9838 - val_auc: 0.9987
# Epoch 24/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0304 - accuracy: 0.9882 - precision: 0.9903 - recall: 0.9839 - auc: 0.9987 - val_loss: 0.0369 - val_accuracy: 0.9883 - val_precision: 0.9904 - val_recall: 0.9841 - val_auc: 0.9987
# Epoch 25/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0331 - accuracy: 0.9884 - precision: 0.9904 - recall: 0.9841 - auc: 0.9987 - val_loss: 0.0394 - val_accuracy: 0.9884 - val_precision: 0.9905 - val_recall: 0.9843 - val_auc: 0.9987
# Epoch 26/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0358 - accuracy: 0.9885 - precision: 0.9906 - recall: 0.9843 - auc: 0.9987 - val_loss: 0.0328 - val_accuracy: 0.9886 - val_precision: 0.9906 - val_recall: 0.9844 - val_auc: 0.9987
# Epoch 27/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0287 - accuracy: 0.9886 - precision: 0.9907 - recall: 0.9844 - auc: 0.9987 - val_loss: 0.0370 - val_accuracy: 0.9887 - val_precision: 0.9908 - val_recall: 0.9845 - val_auc: 0.9987
# Epoch 28/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0308 - accuracy: 0.9887 - precision: 0.9908 - recall: 0.9846 - auc: 0.9987 - val_loss: 0.0340 - val_accuracy: 0.9888 - val_precision: 0.9909 - val_recall: 0.9847 - val_auc: 0.9987
# Epoch 29/50
# 2918/2918 [==============================] - 25s 8ms/step - loss: 0.0351 - accuracy: 0.9888 - precision: 0.9909 - recall: 0.9847 - auc: 0.9987 - val_loss: 0.0297 - val_accuracy: 0.9889 - val_precision: 0.9910 - val_recall: 0.9848 - val_auc: 0.9987
# Epoch 30/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0307 - accuracy: 0.9889 - precision: 0.9910 - recall: 0.9848 - auc: 0.9987 - val_loss: 0.0310 - val_accuracy: 0.9890 - val_precision: 0.9911 - val_recall: 0.9849 - val_auc: 0.9988
# Epoch 31/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0355 - accuracy: 0.9890 - precision: 0.9911 - recall: 0.9849 - auc: 0.9988 - val_loss: 0.0367 - val_accuracy: 0.9891 - val_precision: 0.9911 - val_recall: 0.9850 - val_auc: 0.9988
# Epoch 32/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0525 - accuracy: 0.9891 - precision: 0.9911 - recall: 0.9850 - auc: 0.9988 - val_loss: 0.0983 - val_accuracy: 0.9889 - val_precision: 0.9907 - val_recall: 0.9851 - val_auc: 0.9987
# Epoch 33/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0685 - accuracy: 0.9888 - precision: 0.9905 - recall: 0.9851 - auc: 0.9987 - val_loss: 0.0505 - val_accuracy: 0.9888 - val_precision: 0.9904 - val_recall: 0.9852 - val_auc: 0.9987
# Epoch 34/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0617 - accuracy: 0.9888 - precision: 0.9904 - recall: 0.9852 - auc: 0.9987 - val_loss: 0.0680 - val_accuracy: 0.9888 - val_precision: 0.9902 - val_recall: 0.9853 - val_auc: 0.9987
# Epoch 35/50
# 2918/2918 [==============================] - 24s 8ms/step - loss: 0.0526 - accuracy: 0.9888 - precision: 0.9901 - recall: 0.9854 - auc: 0.9987 - val_loss: 0.1570 - val_accuracy: 0.9886 - val_precision: 0.9897 - val_recall: 0.9855 - val_auc: 0.9986
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
plt.figure(figsize=(10,8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['precision'])
plt.plot(history.history['recall'])
plt.title('DNN Machine Learning Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy', 'Precision','Recall'], loc='upper left')
plt.show()

# %%
# %tensorboard !kill 89177
# Out:
# ERROR: Failed to launch TensorBoard (exited with 2).
# Contents of stderr:
# 2021-05-29 21:39:41.033349: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-05-29 21:39:41.033399: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# usage: tensorboard [-h] [--helpfull] {serve,dev} ...
# tensorboard: error: invalid choice: '!kill' (choose from 'serve', 'dev')

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 89177), started 1:19:43 ago. (Use '!kill 89177' to kill it.)
#       <iframe id="tensorboard-frame-e86f73efab929c0e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e86f73efab929c0e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Testing

# %%
def test_preprocess():
    df_test = pd.read_csv('Datasets/csv_result-KDDTest+.csv')
    df_test.drop(['id'], axis = 'columns' , inplace = True)
    
    #for i in range(11,20):
        #df_train.drop(df_train.columns[i],axis='columns',inplace=True)
        
    col_list = ['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent',
                'count','srv_count','serror_rate','srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate',
                'diff_srv_rate','srv_diff_host_rate','dst_host_count','dst_host_srv_count','dst_host_same_srv_rate',
                'dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate',
                'dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate','class']
    
    df_test = df_test[col_list]
        
    for col in ['protocol_type','flag','service']:
        df_test[col] = df_test[col].astype('category')
    
    label1 = 'Other_service'
    others1 = df_test['service'].value_counts().index[30:]
    # apply new category label
    df_test['service'] = df_test['service'].cat.add_categories([label1])
    df_test['service'] = df_test['service'].replace(others1, label1)

    print('Duplicates after category reduction :',df_test.duplicated().sum())
    df_test['service'].replace({'pop_3':'Other_service','sunrpc':'Other_service',
                                'link':'Other_service','name':'Other_service','echo':'Other_service',
                                'netbios_ns':'Other_service'}, inplace = True)
    
    df_test['class'] = df_test['class'].map( {'normal':0, 'anomaly':1} )
    df_test.drop_duplicates(keep='first',inplace=True)
    print('Duplicates after duplicate drop :',df_test.duplicated().sum())
    
    return df_test
df_test = test_preprocess()
# Out:
# Duplicates after category reduction : 44
# Duplicates after duplicate drop : 0

# %%
print(df_test['protocol_type'].value_counts())
print('======================================')
print(df_test['service'].value_counts())
print('======================================')
print(df_test['flag'].value_counts())
# Out:
# tcp     18828
# udp      2621
# icmp     1043
# Name: protocol_type, dtype: int64
# ======================================
# http             7849
# private          4774
# Other_service    2040
# telnet           1626
# smtp              934
# domain_u          894
# other             835
# ftp_data          833
# ecr_i             752
# ftp               692
# imap4             306
# eco_i             262
# finger            136
# auth               67
# domain             51
# uucp               50
# iso_tsap           48
# bgp                46
# uucp_path          46
# Z39_50             45
# vmnet              43
# nnsp               42
# ctf                41
# courier            40
# whois              40
# Name: service, dtype: int64
# ======================================
# SF        14853
# REJ        3839
# S0         1996
# RSTO        771
# RSTR        669
# S3          249
# SH           73
# S1           21
# S2           15
# OTH           4
# RSTOS0        2
# Name: flag, dtype: int64

# %%
df_test.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'count', 'srv_count',
#        'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
#        'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate',
#        'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'class'],
#       dtype='object')

# %%
len(df_test.columns)
# Out:
# 29

# %%
limit2 = df_test.shape[1]-1
    
X_test = df_test.iloc[:,0:limit2] # train set features
Y_test = df_test.iloc[:,limit2]

# %%
X_test = columnTransformer.transform(X_test)

# %%
X_test.shape
# Out:
# (22492, 64)

# %%
test_predictions = model.predict(X_test)
test_predictions
# Out:
# array([[9.6019268e-01],
#        [9.6019268e-01],
#        [1.2231171e-03],
#        ...,
#        [6.0202867e-02],
#        [1.4522483e-07],
#        [9.6019268e-01]], dtype=float32)

# %%
print(np.unique(test_predictions))
# Out:
# [3.9885439e-12 4.1810344e-12 4.2472085e-12 ... 4.6140742e-01 4.8895991e-01
#  9.6019268e-01]

# %%
test_predictions[5]
# Out:
# array([0.00049183], dtype=float32)

# %%
rounded_test_predictions = []

for i, value in enumerate(test_predictions):
    if value > 0.5:
        rounded_test_predictions.append(1)
    else:
        rounded_test_predictions.append(0)

# %%
def plot_cm(labels, predictions, title = 'Confusion Matrix'):
    cm = confusion_matrix(labels, predictions, normalize= 'true')
    plt.figure(figsize=(4.5,4))
    sns.heatmap(cm, cmap= 'PuBu', annot=True, fmt='.4f', annot_kws=    {'size':16})
    plt.xlabel('Predicted', fontsize=16)
    plt.ylabel('Actual', fontsize=16)
    plt.title(title, fontsize=18)

    print('True Negatives  : {:.4f}'.format(cm[0][0]))
    print('False Positives : {:.4f}'.format(cm[0][1]))
    print('False Negatives : {:.4f}'.format(cm[1][0]))
    print('True Positives  : {:.4f}'.format(cm[1][1]))
    
plot_cm(Y_test,rounded_test_predictions)
# Out:
# True Negatives  : 0.9100
# False Positives : 0.0900
# False Negatives : 0.3491
# True Positives  : 0.6509

# %%
print("Test set accuracy  : {:.4f}".format(accuracy_score(Y_test, rounded_test_predictions)))
print("Test set precision : {:.4f}".format(precision_score(Y_test, rounded_test_predictions)))
print("Test set recall    : {:.4f}".format(recall_score(Y_test, rounded_test_predictions)))
print("Test set F1-score  : {:.4f}".format(f1_score(Y_test, rounded_test_predictions)))
# Out:
# Test set accuracy  : 0.7628
# Test set precision : 0.9049
# Test set recall    : 0.6509
# Test set F1-score  : 0.7572

# %%
from sklearn.metrics import roc_curve, auc
fpr_lr, tpr_lr, _ = roc_curve(Y_test, rounded_test_predictions)
roc_auc_lr = auc(fpr_lr, tpr_lr)

plt.figure()
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr_lr, tpr_lr, lw=3, label='DNN ROC curve (area = {:0.2f})'.format(roc_auc_lr))
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('ROC curve', fontsize=18)
plt.legend(loc='lower right', fontsize=18)
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
plt.axes().set_aspect('equal')
plt.show()
# Out:
# <ipython-input-32-129bfb7c9ca4>:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_aspect('equal')

# %% [markdown]
# ## Saving ML Model and OneHotEncoder/StandardScaler

# %%
# saving model
json_model = model.to_json()
open('DNN_Realtime_Model.json', 'w').write(json_model)
# saving weights
model.save_weights('DNN_model_weights.h5', overwrite=True)

# %%
joblib.dump(columnTransformer,"DNN_Realtime_ColumnTransformer")
# Out:
# ['DNN_Realtime_ColumnTransformer']

# %% [markdown]
# # Hyperparameter Tuning - KerasTuner

# %%
def build_model(hp):
    
    # Hyperparameters
    num_hidden_layers = hp.Int('num_hidden_layers',2,20)
    
    model_tune = keras.Sequential()
    
    #Input Layer
    model_tune.add(Dense(256, input_dim=64, activation='relu', 
                         kernel_initializer='glorot_uniform', 
                         kernel_regularizer=l2(0.01), 
                         bias_regularizer=l2(0.01),
                         bias_initializer='zeros'))
    
    #Hidden Layers
    regularization_coef = hp.Choice('regularization_coef',values = [0.1,0.01,0.001,0.001])
    for i in range(num_hidden_layers):
        model_tune.add(layers.Dense(units=hp.Int('num_neurons' + str(i),
                                                 min_value = 32,
                                                 max_value = 512,
                                                 step = 32),
                                    kernel_regularizer=l2(regularization_coef), 
                                    bias_regularizer=l2(regularization_coef),
                                    activation = 'relu'))
        
    #Output Layer
    model_tune.add(Dense(1, activation='sigmoid'))
    
    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    
    model_tune.compile(loss='binary_crossentropy', 
                  optimizer=keras.optimizers.Adam(learning_rate = learning_rate), 
                  metrics = METRICS)
    
    return model_tune

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='my_dir',
    project_name='DNN_Realtime')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/DNN_Realtime/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/DNN_Realtime/tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 8
# num_hidden_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# regularization_coef (Choice)
# {'default': 0.1, 'conditions': [], 'values': [0.1, 0.01, 0.001, 0.001], 'ordered': True}
# num_neurons0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# num_neurons1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# num_neurons2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# num_neurons3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# num_neurons4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}

# %%
tuner.search(X_train, y_train, epochs=50, validation_split=0.3)
# Out:
# Trial 4 Complete [00h 45m 11s]
# val_accuracy: 0.9960371653238932
#
# Best val_accuracy So Far: 0.9960371653238932
# Total elapsed time: 04h 46m 58s
# INFO:tensorflow:Oracle triggered exit

# %%
best_models = tuner.get_best_models(num_models=2)

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in my_dir/DNN_Realtime
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# num_hidden_layers: 7
# regularization_coef: 0.001
# num_neurons0: 320
# num_neurons1: 320
# learning_rate: 0.001
# num_neurons2: 224
# num_neurons3: 256
# num_neurons4: 384
# num_neurons5: 160
# num_neurons6: 192
# num_neurons7: 224
# num_neurons8: 224
# num_neurons9: 32
# num_neurons10: 352
# num_neurons11: 256
# num_neurons12: 448
# num_neurons13: 64
# num_neurons14: 128
# num_neurons15: 352
# num_neurons16: 64
# num_neurons17: 128
# num_neurons18: 160
# Score: 0.9960371653238932
# Trial summary
# Hyperparameters:
# num_hidden_layers: 5
# regularization_coef: 0.01
# num_neurons0: 160
# num_neurons1: 64
# learning_rate: 0.001
# num_neurons2: 32
# num_neurons3: 32
# num_neurons4: 32
# Score: 0.9952784975369772
# Trial summary
# Hyperparameters:
# num_hidden_layers: 5
# regularization_coef: 0.1
# num_neurons0: 288
# num_neurons1: 128
# learning_rate: 0.0001
# num_neurons2: 320
# num_neurons3: 192
# num_neurons4: 160
# num_neurons5: 480
# num_neurons6: 448
# num_neurons7: 384
# num_neurons8: 32
# num_neurons9: 32
# num_neurons10: 160
# num_neurons11: 96
# num_neurons12: 96
# num_neurons13: 96
# num_neurons14: 384
# num_neurons15: 160
# num_neurons16: 480
# num_neurons17: 32
# num_neurons18: 96
# Score: 0.9819262425104777
# Trial summary
# Hyperparameters:
# num_hidden_layers: 17
# regularization_coef: 0.001
# num_neurons0: 224
# num_neurons1: 480
# learning_rate: 0.001
# num_neurons2: 128
# num_neurons3: 128
# num_neurons4: 416
# num_neurons5: 32
# num_neurons6: 32
# num_neurons7: 32
# num_neurons8: 32
# num_neurons9: 32
# num_neurons10: 32
# num_neurons11: 32
# num_neurons12: 32
# num_neurons13: 32
# num_neurons14: 32
# num_neurons15: 32
# num_neurons16: 32
# Score: 0.8454851309458414
# Trial summary
# Hyperparameters:
# num_hidden_layers: 19
# regularization_coef: 0.1
# num_neurons0: 480
# num_neurons1: 288
# learning_rate: 0.01
# num_neurons2: 384
# num_neurons3: 512
# num_neurons4: 480
# num_neurons5: 512
# num_neurons6: 256
# num_neurons7: 448
# num_neurons8: 160
# num_neurons9: 128
# num_neurons10: 448
# num_neurons11: 160
# num_neurons12: 416
# num_neurons13: 416
# num_neurons14: 416
# num_neurons15: 288
# num_neurons16: 128
# num_neurons17: 32
# num_neurons18: 32
# Score: 0.5448362827301025
